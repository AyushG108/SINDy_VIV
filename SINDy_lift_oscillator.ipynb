# %% [markdown]
# SINDY WORKS WITH ACCELARATION BASED COUPLING MODEL

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
a = 0.002
S = 0.2
zeta = 0.0015
b = 0.4
gamma = 1.21
alpha = 0.02
Ur = 4.9
omega_knot = 0.2* Ur
def odes(state, t, a, omega_knot, zeta):
    x, v, Cl, p = state
    x_dot = v
    v_dot = 2 * a * omega_knot**2 * Cl - x - (2 * zeta * v)
    Cl_dot = 0.239 * p
    p_dot = (0.169 + 0.119 * Cl + 1.536 * p
             - 0.088 * Cl**2 - 0.021 * Cl * p - 0.064 * p**2
             - 0.180 * Cl**3 - 0.769 * Cl**2 * p - 0.180 * Cl * p**2
             - 0.766 * p**3 + b*v)

    return [x_dot, v_dot, Cl_dot, p_dot]
initial_state = [0.0, 0.01, 0, 0]
t_points = np.linspace(0, 30000, 100000)
solution = odeint(odes, initial_state, t_points, args=(a, omega_knot, zeta))
x_t = solution[:, 0]
fig, ax = plt.subplots(figsize=(18, 6))
ax.plot(t_points, x_t, label=f'x(t), Ur={Ur}')
ax.set_title(f'x(t) for Ur={Ur}, Response from SINDy derived Model')
ax.set_xlabel('Time')
ax.set_ylabel('Amplitude x(t)')
ax.legend()
zoom_start, zoom_end = 29500, 30000
mask = (t_points >= zoom_start) & (t_points <= zoom_end)
t_zoom = t_points[mask]
x_zoom = x_t[mask]
axins = inset_axes(ax, width="30%", height="30%", loc='upper right')
axins.plot(t_zoom, x_zoom, label=f'x(t), Ur={Ur}')
axins.set_xlim(zoom_start, zoom_end)
axins.set_ylim(min(x_zoom), max(x_zoom))
axins.set_xticks([])
axins.set_yticks([])
axins.set_title('Zoomed-in view')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-29-6b7588dd34cf>:45: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# Parameters
a = 0.002
S = 0.2
zeta = 0.0015
b = 0.4
gamma = 1.21
alpha = 0.02
Ur = 1.94
omega_knot = 0.2 * Ur

# ODE system
def odes(state, t, a, omega_knot, zeta):
    x, v, Cl, p = state
    x_dot = v
    v_dot = 2 * a * omega_knot**2 * Cl - x - (2 * zeta * v)
    Cl_dot = 0.239 * p
    p_dot = (0.169 + 0.119 * Cl + 1.536 * p
             - 0.088 * Cl**2 - 0.021 * Cl * p - 0.064 * p**2
             - 0.180 * Cl**3 - 0.769 * Cl**2 * p - 0.180 * Cl * p**2
             - 0.766 * p**3 + b*v)
    return [x_dot, v_dot, Cl_dot, p_dot]

# Initial state and time points
initial_state = [0.0, 0.01, 0, 0]
t_points = np.linspace(0, 30000, 100000)

# Solve the ODE system
solution = odeint(odes, initial_state, t_points, args=(a, omega_knot, zeta))
x_t = solution[:, 0]

# Plotting the solution
fig, ax = plt.subplots(figsize=(18, 6))
ax.plot(t_points, x_t, label=f'x(t), Ur={Ur}')
ax.set_title(f'x(t) for Ur={Ur}, Response from SINDy derived Model')
ax.set_xlabel('Time')
ax.set_ylabel('Amplitude x(t)')
ax.legend()

# Define zoom range
zoom_start, zoom_end = 29500, 30000
mask = (t_points >= zoom_start) & (t_points <= zoom_end)
t_zoom = t_points[mask]
x_zoom = x_t[mask]

# Create zoomed-in plot
axins = inset_axes(ax, width="30%", height="30%", loc='upper right')
axins.plot(t_zoom, x_zoom, label=f'x(t), Ur={Ur}')
axins.set_xlim(zoom_start, zoom_end)
axins.set_ylim(min(x_zoom), max(x_zoom))

# Set ticks for the zoomed-in plot
axins.set_xticks(np.linspace(zoom_start, zoom_end, 5))
axins.set_yticks(np.linspace(min(x_zoom), max(x_zoom), 5))

# Display the tick labels for the zoomed-in plot
axins.tick_params(axis='both', which='both', labelsize=8)
axins.set_title('Zoomed-in view', fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-19-2a9244a69068>:64: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# Parameters
a = 0.002
S = 0.2
zeta = 0.0015
b = 0.4
gamma = 1.21
alpha = 0.02
Ur = 10
omega_knot = 0.2 * Ur

# ODE system
def odes(state, t, a, omega_knot, zeta):
    x, v, Cl, p = state
    x_dot = v
    v_dot = 2 * a * omega_knot**2 * Cl - x - (2 * zeta * v)
    Cl_dot = 0.239 * p
    p_dot = (0.169 + 0.119 * Cl + 1.536 * p
             - 0.088 * Cl**2 - 0.021 * Cl * p - 0.064 * p**2
             - 0.180 * Cl**3 - 0.769 * Cl**2 * p - 0.180 * Cl * p**2
             - 0.766 * p**3 + b*v)
    return [x_dot, v_dot, Cl_dot, p_dot]

# Initial state and time points
initial_state = [0.0, 0.01, 0, 0]
t_points = np.linspace(0, 30000, 100000)

# Solve the ODE system
solution = odeint(odes, initial_state, t_points, args=(a, omega_knot, zeta))
x_t = solution[:, 0]

# Plotting the solution
fig, ax = plt.subplots(figsize=(18, 6))
ax.plot(t_points, x_t, label=f'x(t), Ur={Ur}')
ax.set_title(f'x(t) for Ur={Ur}, Response from SINDy derived Model')
ax.set_xlabel('Time')
ax.set_ylabel('Amplitude x(t)')
ax.legend()

# Define zoom range
zoom_start, zoom_end = 29500, 30000
mask = (t_points >= zoom_start) & (t_points <= zoom_end)
t_zoom = t_points[mask]
x_zoom = x_t[mask]

# Create zoomed-in plot
axins = inset_axes(ax, width="30%", height="30%", loc='upper right')
axins.plot(t_zoom, x_zoom, label=f'x(t), Ur={Ur}')
axins.set_xlim(zoom_start, zoom_end)
axins.set_ylim(min(x_zoom), max(x_zoom))

# Set ticks for the zoomed-in plot
axins.set_xticks(np.linspace(zoom_start, zoom_end, 5))
axins.set_yticks(np.linspace(min(x_zoom), max(x_zoom), 5))

# Display the tick labels for the zoomed-in plot
axins.tick_params(axis='both', which='both', labelsize=8)
axins.set_title('Zoomed-in view', fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-22-19711808b47a>:64: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# SINDY derived model

# %%
(Cl)' = -0.005 1 + 5.032 Cl_dot
(Cl_dot)' = 5.023 1 + -12.427 Cl + 50.981 Cl_dot + -5.385 Cl^2 + -29.310 Cl Cl_dot + 0.162 Cl_dot^2
